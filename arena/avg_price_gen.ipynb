# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from evaluator.tester import (
    Tester,
    train_ds,
)

# %%
from models.item import Item


def avg_pricer(item: Item) -> float:
    s = sum([datapoint.price for datapoint in train_ds])
    c = len(train_ds)
    a = s / c
    return a

# %%
Tester.test(avg_pricer)
# Out:
# 1: Guess: $44.88 Truth: $35.00 Error: $9.88 SLE: 0.06 Item: Small Soar Dove Bird Necklace, Delicate ...
# 2: Guess: $44.88 Truth: $25.00 Error: $19.88 SLE: 0.32 Item: Omaha Steaks Gift Card
# 3: Guess: $44.88 Truth: $285.00 Error: $240.12 SLE: 3.35 Item: Ohana Baritone Ukulele Model BK-20CE
# 4: Guess: $44.88 Truth: $4.88 Error: $40.00 SLE: 4.22 Item: BodyGuardz - Pure 2 Edge Glass Screen Pr...
# 5: Guess: $44.88 Truth: $5.00 Error: $39.88 SLE: 4.14 Item: Numer 1 Dad Iron On Decal, Father's Day ...
# 6: Guess: $44.88 Truth: $16.99 Error: $27.89 SLE: 0.88 Item: I Love My Maltese Rhinestone Iron on Tra...
# 7: Guess: $44.88 Truth: $84.99 Error: $40.11 SLE: 0.39 Item: JJ Electronics Amplifier Tubes (T-EL84-J...
# 8: Guess: $44.88 Truth: $18.99 Error: $25.89 SLE: 0.69 Item: Women’s Satin Kimono Robe for Bridesmaid...
# 9: Guess: $44.88 Truth: $22.08 Error: $22.80 SLE: 0.47 Item: Monoprice PLA Plus+ Premium 3D Filament ...
# ...
